# %% [markdown]
# <a href="https://colab.research.google.com/github/alfanfhd/Pembelajaran-Mesin-2026/blob/main/t1_254107023007_alfan_fahat_m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne

# %%
# !pip install pyprep
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# PyPREP adalah library Python yang digunakan untuk melakukan tahap pra-pemrosesan (preprocessing) data sinyal otak atau EEG (Electroencephalography). Library ini mengimplementasikan PREP pipeline standar untuk membersihkan data dari noise (gangguan), mendeteksi saluran (channel) yang buruk, dan melakukan re-referencing agar data sinyal otak siap untuk dianalisis lebih lanjut.

# %%
# !pip install scipy

# %% [markdown]
# Scipy (Scientific Python) adalah library fundamental untuk komputasi saintifik dan matematis di Python. Dalam konteks machine learning, Scipy sangat berguna karena menyediakan berbagai modul dan fungsi matematika tingkat lanjut seperti aljabar linear, optimasi algoritma, perhitungan statistik, serta pemrosesan sinyal dan gambar yang sering menjadi dasar perhitungan algoritma machine learning.

# %%
# !pip install wandb

# %% [markdown]
# wandb (Weights & Biases) adalah library atau platform yang dirancang khusus untuk melacak eksperimen Machine Learning (experiment tracking). Kegunaan utamanya adalah untuk memantau metrik pelatihan model (seperti grafik loss dan akurasi) secara real-time, membandingkan berbagai model dan hyperparameter, serta memvisualisasikan hasil eksperimen agar lebih mudah dianalisis dan didokumentasikan.

# %%
# !pip install pyECG --no-deps
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# pyECG adalah library Python yang khusus dirancang untuk memproses dan menganalisis sinyal rekam aktivitas listrik jantung atau ECG (Electrocardiogram). Kegunaannya mencakup pembersihan sinyal jantung, deteksi gelombang QRS (puncak detak jantung), ekstraksi fitur dari sinyal, dan analisis variabilitas detak jantung (Heart Rate Variability / HRV) untuk keperluan diagnosis klinis atau penelitian.

# %% [markdown]
# Bagian 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang
# penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
#
# *   Pembuatan dan penyebaran konten Deepfake (manipulasi video atau audio menggunakan AI) tanpa izin untuk tujuan penipuan finansial, pemerasan, atau pencemaran nama baik (seperti meniru wajah tokoh publik atau masyarakat sipil dalam video yang tidak pantas).
#
# Referensi:Undang-Undang Republik Indonesia Nomor 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE) beserta perubahannya.https://peraturan.bpk.go.id/Home/Details/37589/uu-no-11-tahun-2008
#
#
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap
# pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya
# (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang
# digunakan.
#
#
# *   Dampak Energi dan Lingkungan:
# Proses pembuatan dan pelatihan model AI (seperti AI generatif atau LLM) membutuhkan daya komputasi dan energi listrik yang sangat masif, bahkan jauh melampaui proses komputasi komputer pada umumnya. Karena masih banyak energi listrik yang berasal dari bahan bakar fosil, penggunaan AI yang terus-menerus ini menghasilkan jejak karbon (carbon footprint) yang sangat tinggi dan mempercepat pemanasan global.
#
# Cara Mengatasinya (Pendapat Pribadi & Solusi):
#
# Penggunaan AI yang Bijak (Edukasi Pengguna): Kita sebagai pengguna harus lebih bijak dan menggunakan AI hanya untuk tugas yang benar-benar membutuhkan bantuan kompleks, bukan untuk hal-hal sepele yang bisa dikerjakan sendiri.
#
# Peralihan ke Energi Hijau: Perusahaan teknologi besar harus dituntut untuk segera menggunakan 100% energi terbarukan (seperti tenaga surya atau angin) untuk menyuplai listrik ke pusat data (data center) mereka.
#
# Pembuatan Model yang Efisien: Pengembang (developer) AI harus mulai fokus menciptakan algoritma AI yang lebih ringan dan hemat daya, bukan sekadar mengejar kepintaran AI tanpa memikirkan dampaknya.
#
# Referensi:
#
# FISIP UIN Syarif Hidayatullah Jakarta. Jejak Karbon di Balik Algoritma: Dilema Lingkungan dalam Era AI. (https://fisip.uinjkt.ac.id/id/jejak-karbon-di-balik-algoritma-dilema-lingkungan-dalam-era-ai)
#
# Kompas Lestari. Dampak Lingkungan AI Kian Besar, Haruskah Berhenti Menggunakannya? (https://lestari.kompas.com/read/2026/03/19/161800586/dampak-lingkungan-ai-kian-besar-haruskah-berhenti-menggunakannya-?page=all)
